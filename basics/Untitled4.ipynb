# %%
from bs4 import BeautifulSoup
import requests

url = 'https://github.com/Aakash12-hub'
r = requests.get(url)
soup = BeautifulSoup(r.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html data-color-mode="auto" data-dark-theme="dark" data-light-theme="light" lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="" href="https://github.githubassets.com" rel="preconnect"/>
# <link href="https://avatars.githubusercontent.com" rel="preconnect"/>
# ...

# %%
c = soup.findAll('a', attrs = {'class':'Link--secondary no-underline no-wrap'})
c
# Out:
# [<a class="Link--secondary no-underline no-wrap" href="https://github.com/Aakash12-hub?tab=followers">
#  <svg aria-hidden="true" class="octicon octicon-people" data-view-component="true" height="16" text="muted" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M5.5 3.5a2 2 0 100 4 2 2 0 000-4zM2 5.5a3.5 3.5 0 115.898 2.549 5.507 5.507 0 013.034 4.084.75.75 0 11-1.482.235 4.001 4.001 0 00-7.9 0 .75.75 0 01-1.482-.236A5.507 5.507 0 013.102 8.05 3.49 3.49 0 012 5.5zM11 4a.75.75 0 100 1.5 1.5 1.5 0 01.666 2.844.75.75 0 00-.416.672v.352a.75.75 0 00.574.73c1.2.289 2.162 1.2 2.522 2.372a.75.75 0 101.434-.44 5.01 5.01 0 00-2.56-3.012A3 3 0 0011 4z" fill-rule="evenodd"></path>
#  </svg>
#  <span class="text-bold color-fg-default">1</span>
#            follower
#  </a>,
#  <a class="Link--secondary no-underline no-wrap" href="https://github.com/Aakash12-hub?tab=following">
#  <span class="text-bold color-fg-default">1</span>
#            following
#  </a>]

# %%
len(c)
# Out:
# 2

# %%
c[0]
# Out:
# <a class="Link--secondary no-underline no-wrap" href="https://github.com/Aakash12-hub?tab=followers">
# <svg aria-hidden="true" class="octicon octicon-people" data-view-component="true" height="16" text="muted" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M5.5 3.5a2 2 0 100 4 2 2 0 000-4zM2 5.5a3.5 3.5 0 115.898 2.549 5.507 5.507 0 013.034 4.084.75.75 0 11-1.482.235 4.001 4.001 0 00-7.9 0 .75.75 0 01-1.482-.236A5.507 5.507 0 013.102 8.05 3.49 3.49 0 012 5.5zM11 4a.75.75 0 100 1.5 1.5 1.5 0 01.666 2.844.75.75 0 00-.416.672v.352a.75.75 0 00.574.73c1.2.289 2.162 1.2 2.522 2.372a.75.75 0 101.434-.44 5.01 5.01 0 00-2.56-3.012A3 3 0 0011 4z" fill-rule="evenodd"></path>
# </svg>
# <span class="text-bold color-fg-default">1</span>
#           follower
# </a>

# %%
h = c[0].findAll('span', attrs = {'class':'text-bold color-fg-default'})
h
# Out:
# [<span class="text-bold color-fg-default">1</span>]

# %%
h[0]
# Out:
# <span class="text-bold color-fg-default">1</span>

# %%
h[0].text
# Out:
# '1'

# %%
#!pip install pandas
import pandas as pd  

Data =[1, 3, 4, 5, 6, 2, 9]  
a = pd.Series(Data)  
a
# Out:
# 0    1
# 1    3
# 2    4
# 3    5
# 4    6
# 5    2
# 6    9
# dtype: int64

# %%
import pandas as pd

Data =[2,7]
jr = pd.Series(Data)
jr
# Out:
# 0    2
# 1    7
# dtype: int64

# %%
import pandas as pd

Data = [6,7,0,'df']
Index = ['a', 'b', 'c', 'd']
shi = pd.Series(Data,Index)
shi
# Out:
# a     6
# b     7
# c     0
# d    df
# dtype: object

# %%
import pandas as pd

Data = ['akash', 'ayushi', 'garima', 'aditya']
Index = ['a', 'b', 'c', 'd']
no = pd.Series(Data,Index)
no
# Out:
# a     akash
# b    ayushi
# c    garima
# d    aditya
# dtype: object

# %%
import pandas as pd

dict1 ={1:'aakash',2:'ayushi',3:'garima',4:'aditya'}
dict2 ={1:24, 2:28, 3:26, 4:23}
Data ={'first':dict1, 'marks obtained':dict2}
sy = pd.DataFrame(Data)
sy
# Out:
#     first  marks obtained
# 1  aakash              24
# 2  ayushi              28
# 3  garima              26
# 4  aditya              23

# %%
import pandas as pd

dict1 ={1:'aakash',2:'ayushi',3:'garima',4:'aditya'}
dict2 ={1:24, 2:28, 3:26, 4:23}
dict3 ={1:24+3, 2:28+2, 3:26+2, 4:23+2}
Data ={'first':dict1, 'marks obtained':dict2, 'total after add':dict3}
sy = pd.DataFrame(Data)
sy
# Out:
#     first  marks obtained  total after add
# 1  aakash              24               27
# 2  ayushi              28               30
# 3  garima              26               28
# 4  aditya              23               25

# %%
import pandas as pd

dict = {'name':['aakash','ayushi','garima','aditya'],
        'course':['java','chain block','gaming','DBMS'],
        'credits':[3,2,2,3]}

df = pd.DataFrame(dict)
df
# Out:
#      name       course  credits
# 0  aakash         java        3
# 1  ayushi  chain block        2
# 2  garima       gaming        2
# 3  aditya         DBMS        3

# %%
df.to_csv('file.csv')
